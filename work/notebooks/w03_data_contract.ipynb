# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
#One row represents a content item (page/query pair) observed on a specific date with search performance metrics.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
#  Field              | Why it is a feature                                                     |
# | ------------------ | ----------------------------------------------------------------------- |
# | `impressions_90d`  | Shows how much search exposure content received in the previous 90 days |
# | `ctr`              | Measures how effectively impressions convert into clicks                |
# | `avg_position`     | Indicates current ranking position in search results                    |
# | `content_age_days` | Older/newer content may behave differently in ranking                   |
# | `weekend_share`    | Captures traffic pattern differences across weekdays/weekends           |

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(DISTINCT content_id, report_date) AS unique_content_date_rows
# FROM fact_daily
# WHERE month = '2026-03';


# SELECT
#     COUNT(*) AS total_rows,
#     COUNT(DISTINCT CONCAT(content_id, '-', report_date)) AS unique_pairs
# FROM fact_daily
# WHERE month='2026-03';

# SELECT
#     COUNTIF(impressions_90d IS NULL) AS missing_impressions,
#     COUNTIF(ctr IS NULL) AS missing_ctr,
#     COUNTIF(avg_position IS NULL) AS missing_position
# FROM fact_daily
# WHERE month='2026-03';

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
#  Data Limits

# 1. Unbalanced history:
# The dataset may contain more observations from high-volume clients or content items. 
# The model may perform better on frequently observed groups and may not generalize equally to smaller groups.

# 2. GSC-only early rows:
# Some early observations rely mainly on Google Search Console signals. 
# The dataset cannot explain business outcomes such as conversions, revenue, or user satisfaction.

# 3. Window overlaps:
# Rolling features such as impressions_90d contain overlapping historical periods across rows.
# Random splits may create overly optimistic evaluation results, so time-aware validation is required.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
